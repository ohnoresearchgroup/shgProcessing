# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = "\\\\arc.auburn.edu\\lab\\ohnogroup\\0827_SHG\\"

# %%
file = "water_shg_300.asc"

data = pd.read_csv(path + file, delimiter='\t', names=['wl', 'counts'], skiprows=37, engine='python')

plt.figure()
plt.plot(data['wl'],data['counts'])
plt.xlim([515,530])
# Out:
# (515.0, 530.0)

# %%
file = "water_shg_1200.asc"

data = pd.read_csv(path + file, delimiter='\t', names=['wl', 'counts'], skiprows=37, engine='python')

plt.figure()
plt.plot(data['wl'],data['counts'])
plt.xlim([515,530])
# Out:
# (515.0, 530.0)

# %%
file = "cv_0pt2micromolar_300.asc"

data = pd.read_csv(path + file, delimiter='\t', names=['wl', 'counts'], skiprows=37, engine='python')
plt.figure()
plt.plot(data['wl'],data['counts'])
#plt.xlim([515,530])
# Out:
# Empty DataFrame
# Columns: [wl, counts]
# Index: []

# %%
file = "cv_0pt2micromolar_1200.asc"

data = pd.read_csv(path + file, delimiter='\t', names=['wl', 'counts'], skiprows=37, engine='python')
print(data)
plt.figure()
plt.plot(data['wl'],data['counts'])
#plt.xlim([515,530])
# Out:
# Empty DataFrame
# Columns: [wl, counts]
# Index: []

# %%
file = "cv_2pt0micromolar_300.asc"

data = pd.read_csv(path + file, delimiter='\t', names=['wl', 'counts'], skiprows=37, engine='python')
print(data)
plt.figure()
plt.plot(data['wl'],data['counts'])
plt.xlim([515,530])
# Out:
#              wl  counts
# 0     413.22433     316
# 1     413.38107     311
# 2     413.53778     306
# 3     413.69449     311
# 4     413.85123     318
# ...         ...     ...
# 1594  661.72626     349
# 1595  661.88086     348
# 1596  662.03540     370
# 1597  662.19000     333
# 1598  662.34460     350
#
# [1599 rows x 2 columns]
# (515.0, 530.0)

# %%
file = "cv_2pt0micromolar_1200.asc"

data = pd.read_csv(path + file, delimiter='\t', names=['wl', 'counts'], skiprows=37, engine='python')
print(data)
plt.figure()
plt.plot(data['wl'],data['counts'])
plt.xlim([515,530])
# Out:
#              wl  counts
# 0     510.01239    3056
# 1     510.04776    3061
# 2     510.08313    3031
# 3     510.11850    3012
# 4     510.15387    3046
# ...         ...     ...
# 1595  565.47247    3176
# 1596  565.50653    3146
# 1597  565.54059    3162
# 1598  565.57465    3154
# 1599  565.60870    3172
#
# [1600 rows x 2 columns]
# (515.0, 530.0)

# %%
file = "cv_20pt0micromolar_300.asc"

data = pd.read_csv(path + file, delimiter='\t', names=['wl', 'counts'], skiprows=37, engine='python')
data['counts'] = data['counts']*2
print(data)
plt.figure()
plt.plot(data['wl'],data['counts'])
plt.xlim([515,530])
# Out:
#              wl  counts
# 0     515.15308     628
# 1     515.30914     662
# 2     515.46521     632
# 3     515.62128     632
# 4     515.77734     644
# ...         ...     ...
# 1594  762.45532     610
# 1595  762.60907     620
# 1596  762.76282     622
# 1597  762.91656     610
# 1598  763.07025     620
#
# [1599 rows x 2 columns]
# (515.0, 530.0)

# %%
file = "cv_20pt0micromolar_1200.asc"

data = pd.read_csv(path + file, delimiter='\t', names=['wl', 'counts'], skiprows=37, engine='python')

print(data)
plt.figure()
plt.plot(data['wl'],data['counts'])
plt.xlim([515,530])
# Out:
#              wl  counts
# 0     510.04776     309
# 1     510.08313     302
# 2     510.11850     304
# 3     510.15387     306
# 4     510.18921     300
# ...         ...     ...
# 1594  565.47247     315
# 1595  565.50653     313
# 1596  565.54059     306
# 1597  565.57465     317
# 1598  565.60870     319
#
# [1599 rows x 2 columns]
# (515.0, 530.0)
